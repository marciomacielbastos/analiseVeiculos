# %%
import re
import pandas as pd
import numpy as np
import time
import os 
import pylab as pl
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as soup
from selenium import webdriver
import scipy.stats as ss
from selenium.webdriver.common.keys import Keys
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Abrir o Navegador para Webscrappin com selenium

# %%
driver = webdriver.Firefox()

# %% [markdown]
# ### Setamos a homepage de Webscrapping a página onde iniciaremos a busca no site do OLX

# %%
home='http://fortaleza.olx.com.br/carros-cat-378'

# %% [raw]
# Para continuar, após uma interrupção, eu já iniciava de uma página avançada

# %%
home='http://fortaleza.olx.com.br/carros-cat-378-p-'

# %% [markdown]
# ### Criamos um Dataframe com espaço para 12000 veículos usados que estão a venda no site da OLX

# %%
carros=df = pd.DataFrame(np.zeros((12000,4)))
carros.columns=['Marca','Modelo','Ano','Valor']

# %% [markdown]
# ### Como não consegui extrair o href referente às URLs a serem visitadas diretamente, criei essa gambiarra usando o BeautifulSoup

# %%
def takeNext(d):#Gambiarra
    sopa=soup(d.page_source.encode('utf-8'))
    k=[]
    for a in sopa.findAll('a', href=True):
        k.append(a['href'])
    return k

# %% [markdown]
# ### Método para extrair os dados de interesse da HTML minerada

# %%
def mineraCarro(tabela,S,j,i):
    #A posicao "j" do array foi passada separadamente para possível correção de erros provocados pela página visitada
    if j>=40:
        return tabela,j,0
    driver.get(S[j])
    try:
        tabela['Marca'][i] = driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[1]/dd[1]').text
        tabela['Modelo'][i] = driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[1]/dd[2]').text
        tabela['Valor'][i] = int(float(driver.find_element_by_xpath('//*[@id="sticky-container"]/div/div/span').text[3:].replace('.','')))
        tabela['Ano'][i] = int(driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[2]/dd[1]').text)
    except: 
        j=j+1
        mineraCarro(tabela,S,j,i)
    time.sleep(5)
    return tabela,j,1

# %% [raw]
# Minerar de uma página avançada exigia alterações em mineraCarro()

# %%
def mineraCarro(tabela,S,j,i):
    #A posicao "j" do array foi passada separadamente para possível correção de erros provocados pela página visitada
    if j>=40:
        return tabela,j,0
    driver.get(S[j])
    try:
        tabela['Marca'][i] = driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[1]/dd[1]').text
        tabela['Modelo'][i] = driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[1]/dd[2]').text
        tabela['Valor'][i] = int(float(driver.find_element_by_xpath('//*[@id="sticky-container"]/div/div/span').text[3:].replace('.','')))
        tabela['Ano'][i] = int(driver.find_element_by_xpath('//*[@id="description-text"]/div/dl[2]/dd[1]').text)
    except: 
        j=j+1
        mineraCarro(tabela,S,j,i)
    time.sleep(5)
    return tabela,j,1

# %% [markdown]
# ### Método para navegação e criação de array de URLs de interesse

# %%
def mineraPagina(S,tabela,posicao):
    S1=S
    j=0
    flag =1
    for i in range(30):
        j=0
        driver.get(S)
        address=takeNext(driver)
        #Extração de somente 40 URLs por página de exibição
        address=address[63:104]
        while j<40:
            tabela,j,flag=mineraCarro(tabela,address,j,posicao)
            posicao+=1
            j+=1
            if flag==0:
                break
        
        num=i+2
        S=S1+'-p-'+str(num)
        if posicao==len(tabela):
            break
    return tabela

# %% [raw]
# Minerar de uma página avançada exigia alterações em mineraCarro()

# %%
def mineraPagina(S,tabela,posicao):
    S1=S
    j=0
    flag =1
    for i in range(12):
        num=i+35
        S=S1+str(num)
        j=0
        driver.get(S)
        address=takeNext(driver)
        #Extração de somente 40 URLs por página de exibição
        address=address[63:104]
        while j<40:
            tabela,j,flag=mineraCarro(tabela,address,j,posicao)
            posicao+=1
            j+=1
            if flag==0:
                break
        if posicao==len(tabela):
            break
    return tabela

# %% [markdown]
# ### Método em ação

# %%
carros=mineraPagina(home,carros,0)

# %%
#exibição do que foi minerado
carros=carros[carros.Marca!=0]
carros
# Out:
#            Marca                               Modelo   Ano  Valor
# 0        Renault                               Duster  2012  48000
# 1      Chevrolet                                Celta  2005  13000
# 2     Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2007  20000
# 3     Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2007  20000
# 4           Ford                               Ranger  2007  44900
# 5           Ford                               Ranger  2007  44900
# 6           Ford                               Ranger  2007  44900
# 7     Volkswagen                                 Polo  2006  18000
# 8           Fiat                                Palio  2007  13000
# 9        Hyundai                               Tucson  2009  37000
# 10    Volkswagen                                 Polo  2013  36000
# 11          Fiat                                 Idea  2010  29200
# 12          Fiat                                 Idea  2010  29200
# 13          Fiat                                Palio  2009  29500
# 14          Fiat                                Palio  2009  29500
# 15          Fiat                                Palio  2009  29500
# 16          Fiat                                Palio  2012  24000
# 17          Fiat                                Palio  2012  24000
# 18        Toyota                              Corolla  2012  53000
# 19        Toyota                              Corolla  2012  53000
# 20    Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2012  26500
# 21       Peugeot                                  308  2013  95000
# 22       Peugeot                                  207  2011  21000
# 23          Fiat                                Palio  2003  14000
# 24           Jac                                   J5  2013  36990
# 25    Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2000   9000
# 26     Chevrolet                              Classic  2008  15000
# 27     Chevrolet                              Classic  2008  15000
# 28     Chevrolet                              Classic  2008  15000
# 29     Chevrolet                              Classic  2008  15000
# 30     Chevrolet                              Classic  2008  15000
# 31        Toyota                                Hilux  2010  98000
# 32    Mitsubishi                                 L200  2000  34000
# 33        Toyota                              Corolla  2010  48000
# 34  Outro Modelo                                Outro  2009   2300
# 35  Outro Modelo                                Outro  2009   2300
# 36    Volkswagen                               Voyage  2011  27000
# 37    Volkswagen                               Voyage  2011  27000
# 38    Volkswagen                               Voyage  2011  27000
# 39    Volkswagen                               Voyage  2011  27000
# 40    Volkswagen                               Voyage  2011  27000
# 41          Ford                             Ecosport  2009  29000
# 42          Ford                             Ecosport  2009  29000
# 43    Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2004   9000
# 44       Citroen                                   C4  2010  27300
# 45    Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2012  20000
# 46     Chevrolet                                 A-10  2007  14500
# 47  Outro Modelo                                 2009     0  18000
# 48          Ford                                F-250  2007  75000
# 49    Volkswagen                               Voyage  2011  28000
# 50    Volkswagen                               Voyage  2011  28000
# 51    Mitsubishi                               Pajero  2008  37900
# 52    Mitsubishi                               Pajero  2011  55900
# 53    Volkswagen                           New Beetle  2008  35000
# 54    Volkswagen  Gol/Parati/Saveiro/Voyage (Pointer)  2014  35900
# 55     Chevrolet                                 S-10  2013  93900
# 56     Chevrolet                                 S-10  2013  93900
# 57     Chevrolet                                Celta  2010  16990
# 58     Chevrolet                                Celta  2006  13800
# 59       Peugeot                                  207  2010  18999
#              ...                                  ...   ...    ...
#
# [294 rows x 4 columns]

# %% [markdown]
# ### Métodos para persistir a tabela minerada

# %%
#carros.to_json('../outputs/carJson3')

# %% [raw]
# Para não confundir eu já colocava outro, pois errei várias vezes por desatenção

# %%
#carros.to_json('../outputs/carJson2')

# %%
#carJson=carJson.reset_index()
#carJson.to_json('../outputs/carJson1')

# %% [markdown]
# ### Método para ler a tabela persistida em json

# %%
carJson=pd.read_json('../outputs/carJson1')

# %%
carJson.reset_index(inplace=True)
carJson.drop('index', axis=1, inplace=True)

# %%
#carJson2=pd.read_json('../outputs/carJson2')

# %%
#Concatenar Dataframes minerados separadamente
#pieces=[carJson2,carJson]
#carJson=pd.concat(pieces)

# %%
#Exibe o DataFrame carJson
carJson
# Out:
#      Ano       Marca Modelo    Valor
# 0   2007  Volkswagen    Gol    16200
# 1   2005  Volkswagen    Gol     9500
# 2   2014        Fiat  Palio    32000
# 3   2008   Chevrolet  Celta    13000
# 4   2007  Volkswagen    Gol    13500
# 5   2010   Chevrolet  Celta    15800
# 6   2010   Chevrolet  Celta    16800
# 7   2010   Chevrolet  Celta    16800
# 8   2010   Chevrolet  Celta    16800
# 9   2010   Chevrolet  Celta    16800
# 10  2006   Chevrolet  Celta    14600
# 11  2006   Chevrolet  Celta    14600
# 12  2004   Chevrolet  Celta    13000
# 13  2012        Fiat  Palio    31900
# 14  2006   Chevrolet  Celta    14600
# 15  2008   Chevrolet  Celta    19000
# 16  2013  Volkswagen    Gol    29900
# 17  2008  Volkswagen    Gol    23000
# 18  2008   Chevrolet  Celta  1500500
# 19  2011   Chevrolet  Celta    20800
# 20  2005   Chevrolet  Celta    13000
# 21  2012        Fiat    Uno    24800
# 22  1996        Fiat    Uno     4500
# 23  2005        Fiat    Uno    12000
# 24  2010        Fiat  Palio    28000
# 25  1996        Fiat    Uno     5500
# 26  1993        Fiat    Uno     5700
# 27  2005        Fiat    Uno    12500
# 28  2012        Fiat    Uno    26000
# 29  2011  Volkswagen    Gol    20900
# 30  2012        Fiat    Uno    23000
# 31  2009        Fiat    Uno    14000
# 32  2014        Fiat    Uno    13000
# 33  2011        Fiat    Uno    24900
# 34  2011        Fiat    Uno    23000
# 35  2004  Volkswagen    Gol     9000
# 36  2013        Fiat    Uno    24900
# 37  1993        Fiat    Uno     5700
# 38  2012        Fiat    Uno    26500
# 39  1995        Fiat    Uno     5500
# 40  2012        Fiat    Uno    26500
# 41  1999  Volkswagen    Gol    16500
# 42  1996        Fiat    Uno     5500
# 43  2012        Fiat    Uno    28000
# 44  2012        Fiat    Uno    22500
# 45  2011        Fiat    Uno    15000
# 46  2013        Fiat  Palio    27000
# 47  2011        Fiat    Uno    24500
# 48  2011        Fiat    Uno    24500
# 49  2009        Fiat    Uno    15000
# 50  2012        Fiat    Uno    23500
# 51  2012        Fiat    Uno    23500
# 52  2012        Fiat    Uno    23500
# 53  2000  Volkswagen    Gol     6700
# 54  1996        Fiat    Uno     5500
# 55  2011        Fiat    Uno    23000
# 56  2012        Fiat    Uno    17800
# 57  2012        Fiat  Palio    26000
# 58  2013        Fiat    Uno    10000
# 59  1994        Fiat    Uno     4600
#      ...         ...    ...      ...
#
# [834 rows x 4 columns]

# %% [markdown]
# ### Limpar dados sem interesse

# %%
carJson.Modelo[carJson.Modelo=='Gol/Parati/Saveiro/Voyage (Pointer)']='Gol'

# %%
carJson.Ano[carJson.Ano==93]=1993

# %%
carJson=carJson[carJson.Marca!=0]
carJson=carJson[carJson.Ano!=0]
carJson=carJson[carJson.Valor!=0]

# %%
carJson['Volume']=pd.Series(np.zeros(len(carJson['Modelo'])))
for i in carJson['Modelo']:
    carJson.Volume[carJson.Modelo==i]=len(carJson[carJson.Modelo==i])
carJson=carJson.sort('Volume',ascending=False)
carJson.groupby('Modelo').head()
# Out:
#                Ano       Marca    Modelo  Valor  Volume
# Modelo
# Gol      0    2007  Volkswagen       Gol  16200      80
#          262  2010  Volkswagen       Gol  19500      80
#          373  2011  Volkswagen       Gol  25000      80
#          718  2011  Volkswagen       Gol  10500      80
#          361  2011  Volkswagen       Gol  25000      80
# Palio    802  2008        Fiat     Palio  18500      75
#          468  2013        Fiat     Palio  30500      75
#          809  2010        Fiat     Palio  21900      75
#          457  2010        Fiat     Palio  16500      75
#          808  2014        Fiat     Palio  29000      75
# Celta    6    2010   Chevrolet     Celta  16800      48
#          612  2010   Chevrolet     Celta  16900      48
#          14   2006   Chevrolet     Celta  14600      48
#          5    2010   Chevrolet     Celta  15800      48
#          623  2009   Chevrolet     Celta  17500      48
# Uno      49   2009        Fiat       Uno  15000      34
#          50   2012        Fiat       Uno  23500      34
#          51   2012        Fiat       Uno  23500      34
#          55   2011        Fiat       Uno  23000      34
#          52   2012        Fiat       Uno  23500      34
# Classic  88   2013   Chevrolet   Classic  25000      33
#          86   2004   Chevrolet   Classic  15500      33
#          91   2004   Chevrolet   Classic  15000      33
#          92   2011   Chevrolet   Classic  22900      33
#          93   2008   Chevrolet   Classic  15000      33
# Corolla  131  2012      Toyota   Corolla  53000      30
#          128  2008      Toyota   Corolla  33500      30
#          129  2009      Toyota   Corolla  43900      30
#          130  2014      Toyota   Corolla  33000      30
#          125  2005      Toyota   Corolla  25800      30
# Hilux    165  2010      Toyota     Hilux  65000      26
#          159  2009      Toyota     Hilux  95000      26
#          162  2010      Toyota     Hilux  77000      26
#          163  2006      Toyota     Hilux  74000      26
#          170  2008      Toyota     Hilux  85000      26
# Pajero   202  2010  Mitsubishi    Pajero  65500      25
#          199  1999  Mitsubishi    Pajero  18500      25
#          198  2010  Mitsubishi    Pajero  67000      25
#          196  2007  Mitsubishi    Pajero  46500      25
#          195  2006  Mitsubishi    Pajero  57000      25
# Ecosport 218  2011        Ford  Ecosport  36000      22
#          229  2011        Ford  Ecosport  37000      22
#          228  2011        Ford  Ecosport  36000      22
#          227  2005        Ford  Ecosport  21900      22
#          225  2004        Ford  Ecosport  19000      22
# Corsa    244  1996   Chevrolet     Corsa   7500      21
#          254  1995   Chevrolet     Corsa   7200      21
#          253  1995   Chevrolet     Corsa   7500      21
#          252  2002   Chevrolet     Corsa  12700      21
#          251  2003   Chevrolet     Corsa  12500      21
# Siena    280  2008        Fiat     Siena  20000      20
#          278  2013        Fiat     Siena  35000      20
#          277  2010        Fiat     Siena  21900      20
#          276  2012        Fiat     Siena  25500      20
#          274  2007        Fiat     Siena  15500      20
# 207      292  2012     Peugeot       207  23500      19
#          298  2010     Peugeot       207  18999      19
#          300  2010     Peugeot       207  19000      19
#          294  2011     Peugeot       207  21000      19
#          302  2013     Peugeot       207  41990      19
#                ...         ...       ...    ...     ...
#
# [342 rows x 5 columns]

# %% [markdown]
# ### Tabela extraida de http://www.fenabrave.org.br/rel_mais_vendidos.asp, não consegui fazer o webscrapping

# %%
tabela=pd.DataFrame(np.zeros((40,3)))
tabela.columns=['Modelo','Quantidade','Data']

# %%
tabela.Modelo[0]='Palio'
tabela.Quantidade[0]=687
tabela.Modelo[1]='Onix'
tabela.Quantidade[1]=456
tabela.Modelo[2]='Gol'
tabela.Quantidade[2]=414
tabela.Modelo[3]='Siena'
tabela.Quantidade[3]=337
tabela.Modelo[4]='HB20'
tabela.Quantidade[4]=271
tabela.Modelo[5]='Prisma'
tabela.Quantidade[5]=266
tabela.Modelo[6]='Classic'
tabela.Quantidade[6]=247
tabela.Modelo[7]='HB20S'
tabela.Quantidade[7]=223
tabela.Modelo[8]='Uno'
tabela.Quantidade[8]=208
tabela.Modelo[9]='Corolla'
tabela.Quantidade[9]=206
tabela.Modelo[10]='Ka'
tabela.Quantidade[10]=166
tabela.Modelo[11]='Fox'
tabela.Quantidade[11]=164
tabela.Modelo[12]='Etios'
tabela.Quantidade[12]=159
tabela.Modelo[13]='Up'
tabela.Quantidade[13]=133
tabela.Modelo[14]='Cobalt'
tabela.Quantidade[14]=117
tabela.Modelo[15]='Fit'
tabela.Quantidade[15]=116
tabela.Modelo[16]='Sandero'
tabela.Quantidade[16]=93
tabela.Modelo[17]='Celta'
tabela.Quantidade[17]=79
tabela.Modelo[18]='208'
tabela.Quantidade[18]=79
tabela.Modelo[19]='Voyge'
tabela.Quantidade[19]=75
tabela.Data=pd.Period('2014-12')

# %%
tabela.Modelo[20]='Palio'
tabela.Quantidade[20]=628
tabela.Modelo[21]='Onix'
tabela.Quantidade[21]=421
tabela.Modelo[22]='Gol'
tabela.Quantidade[22]=326
tabela.Modelo[23]='Siena'
tabela.Quantidade[23]=319
tabela.Modelo[24]='Prisma'
tabela.Quantidade[24]=295
tabela.Modelo[25]='HB20'
tabela.Quantidade[25]=269
tabela.Modelo[26]='HB20S'
tabela.Quantidade[26]=217
tabela.Modelo[27]='Classic'
tabela.Quantidade[27]=208
tabela.Modelo[28]='Corolla'
tabela.Quantidade[28]=208
tabela.Modelo[29]='Fox'
tabela.Quantidade[29]=182
tabela.Modelo[30]='Uno'
tabela.Quantidade[30]=160
tabela.Modelo[31]='Ka'
tabela.Quantidade[31]=156
tabela.Modelo[32]='Up'
tabela.Quantidade[32]=146
tabela.Modelo[33]='Etios'
tabela.Quantidade[33]=144
tabela.Modelo[34]='Cobalt'
tabela.Quantidade[34]=140
tabela.Modelo[35]='Voyage'
tabela.Quantidade[35]=130
tabela.Modelo[36]='Fit'
tabela.Quantidade[36]=104
tabela.Modelo[37]='Sandero'
tabela.Quantidade[37]=87
tabela.Modelo[38]='Civic'
tabela.Quantidade[38]=86
tabela.Modelo[39]='Etios Sedan'
tabela.Quantidade[39]=80
tabela.Data[20:]=pd.Period('2014-11')

# %%
TABELA=pd.DataFrame(np.array(tabela.groupby('Modelo').Quantidade.sum().values))
TABELA.index=tabela.groupby('Modelo').Quantidade.sum().index
TABELA.sort(0,ascending=False)
# Out:
#                 0
# Modelo
# Palio        1315
# Onix          877
# Gol           740
# Siena         656
# Prisma        561
# HB20          540
# Classic       455
# HB20S         440
# Corolla       414
# Uno           368
# Fox           346
# Ka            322
# Etios         303
# Up            279
# Cobalt        257
# Fit           220
# Sandero       180
# Voyage        130
# Civic          86
# Etios Sedan    80
# Celta          79
# 208            79
# Voyge          75
#
# [23 rows x 1 columns]

# %% [raw]
# Escolhi os 3 carros mais emplacados no Ceará nos meses de Novembro e Dezembro para realizar a comparação com as ofertas do OLX

# %%
Palio=carJson[carJson.Modelo=='Palio']
Gol=carJson[carJson.Modelo=='Gol']
Siena=carJson[carJson.Modelo=='Siena']

# %% [markdown]
# ### Estatísticas do Palio

# %%
Palio=Palio.sort('Ano', ascending=False)
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Palio.Valor,15),color='black',label='Trend')
plt.plot(Palio['Valor'].values,'.')
plt.legend()
plt.grid()
plt.title('Valor do Palio com o envelhecimento')
plt.show()

# %%
Palio=Palio.sort('Ano', ascending=False)
plt.grid()
plt.title('Volume de Palio por ano')
plt.hist(Palio.Ano.values,bins=25)
plt.show()

# %%
print ('Palio mais caro valor: %d'%Palio['Valor'].max())
print ('Palio mais barato valor: %d'%Palio['Valor'].min())
print ('Desvio padrão dos valores dos Palios = %f'%Palio['Valor'].std())
print ('Palio mais novo ano: %d'%Palio['Ano'].max())
print ('Palio mais velho ano: %d'%Palio['Ano'].min())
print ('Desvio padrão dos anos dos Palios = %f'%Palio['Ano'].std())
# Out:
# Palio mais caro valor: 90000
# Palio mais barato valor: 5999
# Desvio padrão dos valores dos Palios = 10937.918227
# Palio mais novo ano: 2014
# Palio mais velho ano: 1997
# Desvio padrão dos anos dos Palios = 4.657378

# %% [markdown]
# ### Estatísticas do Gol

# %%
Gol=Gol.sort('Ano', ascending=False)
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Gol.Valor,15),color='black',label='Trend')
plt.plot(Gol.Valor,'.')
plt.legend()
plt.grid()
plt.title('Valor do Gol com o envelhecimento')
plt.show()

# %%
Gol=Gol.sort('Ano', ascending=False)
plt.grid()
plt.title('Volume de Gol por ano')
plt.hist(Palio.Ano.values,bins=25)
plt.show()

# %%
print ('Gol mais caro valor: %d'%Gol['Valor'].max())
print ('Gol mais barato valor: %d'%Gol['Valor'].min())
print ('Desvio padrão dos valores dos Gols = %f'%Gol['Valor'].std())
print ('Gol mais novo ano: %d'%Gol['Ano'].max())
print ('Gol mais velho ano: %d'%Gol['Ano'].min())
print ('Desvio padrão dos anos dos Gols = %f'%Gol['Ano'].std())
# Out:
# Gol mais caro valor: 37200
# Gol mais barato valor: 4500
# Desvio padrão dos valores dos Gols = 7791.072218
# Gol mais novo ano: 2015
# Gol mais velho ano: 1994
# Desvio padrão dos anos dos Gols = 5.139571

# %% [markdown]
# ### Estatísticas do Siena

# %%
Siena=Siena.sort('Ano', ascending=False)
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Siena.Valor,7),color='black',label='Trend')
plt.plot(Siena.Valor,'.')
plt.legend()
plt.grid()
plt.title('Valor do Siena com o envelhecimento')
plt.show()

# %%
Siena=Siena.sort('Ano', ascending=False)
plt.grid()
plt.title('Volume de Siena por ano')
plt.hist(Siena.Ano.values,bins=25)
plt.show()

# %%
print ('Siena mais caro valor: %d'%Siena['Valor'].max())
print ('Siena mais barato valor: %d'%Siena['Valor'].min())
print ('Desvio padrão dos valores dos Sienas = %f'%Siena['Valor'].std())
print ('Siena mais novo ano: %d'%Siena['Ano'].max())
print ('Siena mais velho ano: %d'%Siena['Ano'].min())
print ('Desvio padrão dos anos dos Sienas = %f'%Siena['Ano'].std())
# Out:
# Siena mais caro valor: 45000
# Siena mais barato valor: 15500
# Desvio padrão dos valores dos Sienas = 6876.188892
# Siena mais novo ano: 2014
# Siena mais velho ano: 2007
# Desvio padrão dos anos dos Sienas = 1.922170

# %% [raw]
# Percebemos que, apesar de menos ofertas à revenda(como esperado pelo volume de emplacamento), a desvalorização é mais acentuada
# na ordem Palio, Gol, Siena.

# %%
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Palio.Valor,15),color='blue',label='Trend-Palio')
plt.plot(pl.movavg(Gol.Valor,15),color='green',label='Trend-Gol')
plt.plot(pl.movavg(Siena.Valor,2),color='red',label='Trend-Siena')
plt.legend()
plt.grid()
plt.show()

# %% [raw]
# Analisaremos a desvalorização dos carros a diesel frente aos a gasolina

# %%
Hilux=carJson[carJson.Modelo=='Hilux']
Pajero=carJson[carJson.Modelo=='Pajero']

# %% [markdown]
# ### Estatísticas Pajero

# %%
Pajero=Pajero.sort('Ano', ascending=False)
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Pajero.Valor,8),color='black',label='Trend')
plt.plot(Pajero.Valor,'.')
plt.legend()
plt.grid()
plt.title('Valor da Pajero com o envelhecimento')
plt.show()

# %%
Pajero=Pajero.sort('Ano', ascending=False)
plt.grid()
plt.title('Volume de Pajero por ano')
plt.hist(Pajero.Ano.values,bins=25)
plt.show()

# %%
print ('Pajero mais caro valor: %d'%Pajero['Valor'].max())
print ('Pajeros mais barato valor: %d'%Pajero['Valor'].min())
print ('Desvio padrão dos valores das Pajeros = %f'%Pajero['Valor'].std())
print ('Pajeros mais novo ano: %d'%Pajero['Ano'].max())
print ('Pajeros mais velho ano: %d'%Pajero['Ano'].min())
print ('Desvio padrão dos anos das Pajeros = %f'%Pajero['Ano'].std())
# Out:
# Pajero mais caro valor: 86900
# Pajeros mais barato valor: 18500
# Desvio padrão dos valores das Pajeros = 16172.456008
# Pajeros mais novo ano: 2015
# Pajeros mais velho ano: 1999
# Desvio padrão dos anos das Pajeros = 3.594904

# %% [markdown]
# ### EStatísticas das Hilux

# %%
Hilux=Hilux.sort('Ano', ascending=False)
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Hilux.Valor,8),color='black',label='Trend')
plt.plot(Hilux.Valor,'.')
plt.legend()
plt.grid()
plt.title('Valor da Hilux com o envelhecimento')
plt.show()

# %%
Hilux=Hilux.sort('Ano', ascending=False)
plt.grid()
plt.title('Volume de Hilux por ano')
plt.hist(Hilux.Ano.values,bins=25)
plt.show()

# %%
print ('Hilux mais caro valor: %d'%Hilux['Valor'].max())
print ('Hilux mais barato valor: %d'%Hilux['Valor'].min())
print ('Desvio padrão dos valores das Hilux = %f'%Hilux['Valor'].std())
print ('Hilux mais novo ano: %d'%Hilux['Ano'].max())
print ('Hilux mais velho ano: %d'%Hilux['Ano'].min())
print ('Desvio padrão dos anos das Hilux = %f'%Hilux['Ano'].std())
# Out:
# Hilux mais caro valor: 130000
# Hilux mais barato valor: 41000
# Desvio padrão dos valores das Hilux = 20636.064398
# Hilux mais novo ano: 2012
# Hilux mais velho ano: 2000
# Desvio padrão dos anos das Hilux = 3.124100

# %% [raw]
#     Análise Comparativa amostral entre carros com motor a diesel e o Palio

# %%
plt.figure(figsize=(8,5))
plt.plot(pl.movavg(Palio.Valor,15),color='blue',label='Trend-Palio')
plt.plot(pl.movavg(Pajero.Valor,7),color='green',label='Trend-Pajero')
plt.plot(pl.movavg(Hilux.Valor,7),color='red',label='Trend-Hilux')
plt.legend()
plt.grid()
plt.show()

# %% [raw]
# Aparentemente os valores dos carros estão em descordância com a realidade, pois as Hilux aparecem mais cara que as Pajeros, além de serem mais velhas. No entanto, analisando somente a linha de tendência, verificamos que a ordem de desvalorização segue: Palio<Pajero<Hilux

# %% [raw]
# Sabemos que as vendas variam de estado para estado, mas usaremos a tabela nacional de emplacamentos como medida avaliativa de veículos

# %% [markdown]
# ### WebScrappin da página da revista Quatro Rodas

# %%
driver = webdriver.Firefox()

# %%
pagina='http://quatrorodas.abril.com.br/autoservico/top50/2014.shtml'

# %%
driver.get(pagina)

# %%
Qrodas=pd.DataFrame(np.zeros((50,12)))

# %%
Qrodas.columns=['CARRO','JANEIRO','FEVEREIRO','MARÇO','ABRIL','MAIO','JUNHO','JULHO','AGOSTO','SETEMBRO','OUTUBRO','NOVEMBRO']

# %%
for i in range(50):
    k=i+2
    Qrodas['CARRO'][i]=driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[2]').text
    Qrodas['JANEIRO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[3]').text.replace('.','')))
    Qrodas['FEVEREIRO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[4]').text.replace('.','')))
    Qrodas['MARÇO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[5]').text.replace('.','')))
    Qrodas['ABRIL'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[6]').text.replace('.','')))
    Qrodas['MAIO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[7]').text.replace('.','')))
    Qrodas['JUNHO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[8]').text.replace('.','')))
    Qrodas['JULHO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[9]').text.replace('.','')))
    Qrodas['AGOSTO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[10]').text.replace('.','')))
    Qrodas['SETEMBRO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[11]').text.replace('.','')))
    Qrodas['OUTUBRO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[12]').text.replace('.','')))
    Qrodas['NOVEMBRO'][i]=int(float(driver.find_element_by_xpath('//*[@id="container-materia"]/div[3]/table/tBody/tr['+str(k)+']/td[13]').text.replace('.','')))

# %%
Qrodas
# Out:
#                       CARRO  JANEIRO  FEVEREIRO  MARÇO  ABRIL   MAIO  JUNHO  \
# 0                Fiat Palio    12603      13017  12872  15408  14910  14079
# 1            Volkswagen Gol    21671      14076  12545  16964  15188  13166
# 2               Fiat Strada    12367      13456  13017  13294  12611  10559
# 3            Chevrolet Onix     9288       9561  12245  13247  11694  10993
# 4              Hyundai HB20     9612       8819   8312   9714   9755   9528
# 5                  Fiat Uno    13628      10409  10275  11286   7871   7580
# 6               Ford Fiesta    13179       8915   9045  12042  10976  10701
# 7                Fiat Siena    11413       9329   7716   8940   8979   8543
# 8   Volkswagen Fox/CrossFox    11267       9293   7313   7770   8012   6834
# 9           Renault Sandero     9153       6317   6006   8746   9910   6830
# 10         Chevrolet Prisma     6023       4938   5603   8122   7355   7219
# 11       Volkswagen Saveiro     5496       5069   4383   5420   7314   6721
# 12        Volkswagen Voyage     6798       5788   5088   5977   7592   6953
# 13           Toyota Corolla     2857       3020   2945   5565   5740   5000
# 14            Volkswagen Up      239       2115   3517   5198   5743   6223
# 15            Ford EcoSport     5284       3940   3483   4734   4541   4015
# 16              Honda Civic     3981       4019   4392   5774   4700   4083
# 17            Chevrolet S10     4120       3655   3344   4742   5018   4078
# 18                Honda Fit     3457       2669   2645   2923   4029   4347
# 19           Renault Duster     4633       3171   2984   3631   3959   3918
# 20         Chevrolet Cobalt     3884       3513   2633   3571   3733   3078
# 21            Hyundai HB20S     3927       3819   3680   4451   4954   4822
# 22             Toyota Hilux     3231       2800   3052   3523   3616   3230
# 23          Chevrolet Celta     5374       3953   3400   4252   4421   3046
# 24        Chevrolet Classic     5293       2814   2345   2677   4499   4725
# 25            Renault Logan     3089       3352   3273   4086   4083   3538
# 26       Toyota Etios Hatch     2682       2767   2587   3438   2961   2473
# 27           Chevrolet Spin     3044       2496   2435   3254   2961   2633
# 28        Chevrolet Montana     2801       3455   3159   3781   2471   2319
# 29                  Ford Ka     2193        837    176     62     16     21
# 30               Citroën C3     2991       2937   2398   2332   2508   2334
# 31       Toyota Etios Sedan     2254       1872   1820   2210   2240   1859
# 32               Fiat Punto     3623       2478   1805   2270   2178   2281
# 33             Fiat Fiorino     1458       2146   1575   1823   2219   1915
# 34    Chevrolet Cruze Sedan     2501       1845   1423   1437   1651   1619
# 35              Ford Ranger     1887       1615   1607   2342   2139   1766
# 36             Nissan March     1805       1365   1076   1276   1696   2131
# 37              Peugeot 208     3033       1924   1606   1814   1829   1562
# 38               Ford Focus     1749       1988   2002   2034   1666   1428
# 39               Honda City     2658       1952   2072   2314   1424   1091
# 40          Mitsubishi L200     1742       1575   1457   1738   1725   1534
# 41             Renault Clio     2641       1355    611    933   1427   1285
# 42       Toyota Etios Sedan     2254       1872   1820   2210   2240   1859
# 43           Hyundai Tucson     1529       1278   1181   1610   1481   1614
# 44       Fiat Palio Weekend     1535       1521   1488   1417   1379   1388
# 45        Volkswagen Amarok     1896       1582   1064   1359   1726   1332
# 46                Fiat Idea     1901       1686   1340   1522   1607   1583
# 47    Chevrolet Cruze Hatch     2359       1340   1035   1637   1724   1105
# 48          Volkswagen Golf     1979       1664   1392   1504   1393   1337
# 49             Hyundai ix35     1052        965    920   1332   1424   1333
#
#     JULHO  AGOSTO  SETEMBRO  OUTUBRO  NOVEMBRO
# 0   15989   14305     15907    16622     15399
# 1   14347   14198     12583    12454     12024
# 2   12585   12850     14225    13380     11435
# 3   14015   10285     13483    13588     14484
# 4   10857    9074      9904    10603     10688
# 5    9613   10922      8749    11192     10473
# 6   10591    8505      6490     5891      5159
# 7    8949    8469      9518     8221      7464
# 8    7284    8348      8470     9683      7543
# 9    5425    7278      7488     7006      8309
# 10   8498    6717      8353     8342      7658
# 11   7294    7022      7780     8437      8643
# 12   7181    6843      5565     6530      5195
# 13   6129    5944      6050     6325      6133
# 14   6316    5846      6272     6441      5283
# 15   5287    4735      4563     4523      4111
# 16   4246    4575      4684     4038      3508
# 17   4471    3861      4760     4420      3922
# 18   4482    4880      5808     5371      5383
# 19   4040    3471      4040     4772      4431
# 20   4551    3627      4564     4518      4407
# 21   5334    4593      5137     5673      6189
# 22   4027    3363      3781     3898      3697
# 23   2121    1257      1812     4218      4006
# 24   5051    4085      5143     3863      3398
# 25   4304    4027      4937     3417      2949
# 26   3120    3234      3394     4016      3959
# 27   3688    2995      3855     3006      3198
# 28   2446    1754      3307     4305      3258
# 29     50     319      7093     9603     10748
# 30   2230    2272      2210     2070      2085
# 31   2200    2170      2460     2937      2822
# 32   2219    1553      1396     1298      1504
# 33   2250    1972      2262     2595      1901
# 34   1982    1559      1860     2393      3665
# 35   2325    2153      2025     2056      1906
# 36   2081    2292      2559     2503      2861
# 37   1738    1798      2137     1925      1740
# 38   2260    2218      1580     1669      1508
# 39   1282     937       713     2524      3077
# 40   1710    1554      2082     1669      1564
# 41   1896    2239      2389     1618      1667
# 42   2200    2170      2460     2937      2822
# 43   1632    1424      1653     1633      1328
# 44   1615    1245      1796     1527      1364
# 45   1432    1444      1327     1337      1370
# 46   1598    1206      1207     1153       905
# 47    961     905      1430     1157      1628
# 48   1311    1359      1371      946       729
# 49   1547    1304      1393     1426      1156
#
# [50 rows x 12 columns]

# %%
Qrodas.to_json('../outputs/QrodasJson')

# %% [markdown]
# ### Fiat Palio

# %%
ARR=Qrodas[Qrodas.CARRO=='Fiat Palio']
ARR.drop('CARRO',1,inplace=True)
ARR=ARR.values
ARR=ARR[0]
plt.figure(figsize=(8,5))
plt.plot(ARR,color='black')
plt.plot(ARR,'o')
plt.legend()
plt.grid()
plt.title('Palios emplacados no Brasil em 2014')
plt.show()

# %%
print ('Valor Total de Palio vendidos em 2014 até novembro: %d'%ARR.sum())
# Out:
# Valor Total de Palio vendidos em 2014 até novembro: 161111

# %% [markdown]
# ### Volkswagen Gol

# %%
ARR=Qrodas[Qrodas.CARRO=='Volkswagen Gol']
ARR.drop('CARRO',1,inplace=True)
ARR=ARR.values
ARR=ARR[0]
plt.figure(figsize=(8,5))
plt.plot(ARR,color='black')
plt.plot(ARR,'o')
plt.legend()
plt.grid()
plt.title('Volkswagen Gol emplacados no Brasil em 2014')
plt.show()

# %%
print ('Valor Total de Gol vendidos em 2014 até novembro: %d'%ARR.sum())
# Out:
# Valor Total de Gol vendidos em 2014 até novembro: 159216

# %% [markdown]
# ### Fiat Siena

# %%
ARR=Qrodas[Qrodas.CARRO=='Fiat Siena']
ARR.drop('CARRO',1,inplace=True)
ARR=ARR.values
ARR=ARR[0]
plt.figure(figsize=(8,5))
plt.plot(ARR,color='black')
plt.plot(ARR,'o')
plt.legend()
plt.grid()
plt.title('Fiat Siena emplacados no Brasil em 2014')
plt.show()

# %%
print ('Valor Total de Siena vendidos em 2014 até novembro: %d'%ARR.sum())
# Out:
# Valor Total de Siena vendidos em 2014 até novembro: 97541

# %% [markdown]
# ## Conclusão

# %% [raw]
# Pelo trabalho verificamos que o Fiat Palio está na frente dos demais veículos, de uma maneira geral. Na análise para o Ceará de ofertas no site do site OLX, verificamos volume de revenda aproximadamente ingual ao Gol(Mais encontrados), menor desvalorização. Pela tabela da Fenabran-CE,foi encontrado maior interesse. Pela última análise percebemos uma tendência de aumento das vendas no Brasil, enquanto os concorrentes apresentam tendência de retração nas vendas. Pela tabela geral de vendas do Brasil, verificamos que os gostos por veículos varia de região para região, mas os dois mais vendidos, são os mesmo, nas mesma ordem tanto na tabela Ceará, quanto Brasil.
#
# Para futuros trabalhos, seria possível fazer uma análise de sentimentos pelo Twitter para verificar a impressão do público em relação aos carros mais vendidos no Brasil.
